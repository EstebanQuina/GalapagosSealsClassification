# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import os
import cv2 # Using OpenCV for image loading/resizing
from tqdm.notebook import tqdm # For progress bars

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Ensure you have a GPU available for faster training
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
if not tf.config.experimental.list_physical_devices('GPU'):
    print("WARNING: No GPU found. Training will be extremely slow on CPU. Please enable GPU runtime: Runtime -> Change runtime type -> GPU.")

# ----------------------------------------------------------------------
# Step 1: Mount Google Drive (if you haven't already in this session)
# ----------------------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive')

# ----------------------------------------------------------------------
# Step 2: Load and Prepare Your Full Dataset
# ----------------------------------------------------------------------
# --- IMPORTANT: Adjust this path to your combined dataset folder ---
data_dir = '/content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/combined_dataset_for_kfold'

image_paths = []
labels = []

# Assuming your class folders are directly inside data_dir
class_names = sorted(os.listdir(data_dir))
class_to_idx = {name: i for i, name in enumerate(class_names)}

print(f"Detected classes: {class_names}")

for class_name in class_names:
    class_path = os.path.join(data_dir, class_name)
    if os.path.isdir(class_path): # Ensure it's a directory
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            if os.path.isfile(img_path): # Ensure it's a file
                image_paths.append(img_path)
                labels.append(class_to_idx[class_name])
    else:
        print(f"Warning: '{class_path}' is not a directory. Skipping.")

image_paths = np.array(image_paths)
labels = np.array(labels)

print(f"\nTotal number of samples loaded for K-fold: {len(image_paths)}")
print(f"Initial Class distribution: {np.bincount(labels)}")

# Define input shape for InceptionV3
IMG_HEIGHT, IMG_WIDTH = 299, 299 # InceptionV3 typically uses 299x299
NUM_CLASSES = len(class_names)
BATCH_SIZE = 32 # Adjust as needed based on GPU memory

# Data preprocessing function (loading, resizing, normalization)
# This will be mapped to the tf.data.Dataset
def load_and_preprocess_image(image_path, label, img_size=(IMG_HEIGHT, IMG_WIDTH)):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, img_size)
    img = preprocess_input(img) # InceptionV3 specific preprocessing
    label = tf.one_hot(label, NUM_CLASSES) # Convert to one-hot encoding
    return img, label

# Data augmentation function (to be used in tf.data.Dataset map for training)
def augment_image(image, label):
    # Apply your augmentations here (based on your previous oversampling strategy)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    # The following lines were causing the AttributeError and are commented out:
    # image = tf.image.random_zoom(image, zoom_factor=(0.8, 1.2)) # Example zoom
    # image = tf.image.random_rotation(image, factor=0.1) # Example rotation

    # If you still want these augmentations, consider using:
    # - tf.keras.layers.RandomRotation, RandomZoom, etc. applied after batching
    # - Or updating your TensorFlow version (e.g., to 2.3+)

    return image, label

# ----------------------------------------------------------------------
# Step 3: Define Your Model Building Function
# ----------------------------------------------------------------------
def build_inceptionv3_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze base model layers (optional, but common for transfer learning)
    # You can unfreeze some layers for fine-tuning after initial training if desired
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom classification head
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x) # Increased units slightly from previous example for potential improvement
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# ----------------------------------------------------------------------
# Step 4: Implement Your Hybrid Balancing Strategy (within the fold)
# ----------------------------------------------------------------------
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils import class_weight

def apply_hybrid_balancing_to_fold(X_train_paths, y_train_labels, class_names):
    # 1. Undersampling on the majority class
    # Use the indices for sampling to apply back to paths and labels
    indices = np.arange(len(X_train_paths)).reshape(-1, 1) # Dummy features for imblearn

    rus = RandomUnderSampler(sampling_strategy='majority', random_state=42)
    resampled_indices_dummy, y_resampled_labels = rus.fit_resample(indices, y_train_labels)

    X_resampled_paths = X_train_paths[resampled_indices_dummy.flatten()]

    # 2. Class Weights (implicitly handles "oversampling" in terms of loss contribution)
    # These weights tell the loss function to give more importance to the minority class samples
    unique_classes = np.unique(y_resampled_labels)
    # Ensure correct ordering of classes if needed, for class_weight
    weights = class_weight.compute_class_weight(class_weight='balanced',
                                                classes=np.array(range(len(class_names))), # Use all possible class indices
                                                y=y_resampled_labels)
    class_weights_dict = dict(zip(range(len(class_names)), weights))

    return X_resampled_paths, y_resampled_labels, class_weights_dict

# ----------------------------------------------------------------------
# Step 5: K-Fold Cross-Validation Loop
# ----------------------------------------------------------------------
N_SPLITS = 5 # Using 5 folds is a good balance between computational cost and statistical robustness
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)

fold_results = [] # To store metrics for each fold

for fold_idx, (train_index, val_index) in enumerate(skf.split(image_paths, labels)):
    print(f"\n--- Starting Fold {fold_idx + 1}/{N_SPLITS} ---")

    # Split data for the current fold
    X_train_fold_paths, X_val_fold_paths = image_paths[train_index], image_paths[val_index]
    y_train_fold_labels, y_val_fold_labels = labels[train_index], labels[val_index]

    print(f"  Train samples in fold: {len(X_train_fold_paths)}")
    print(f"  Validation samples in fold: {len(X_val_fold_paths)}")
    print(f"  Train labels distribution (before balancing): {np.bincount(y_train_fold_labels)}")
    print(f"  Val labels distribution: {np.bincount(y_val_fold_labels)}")

    # Apply Hybrid Balancing ONLY to the training data of the current fold
    X_train_balanced_paths, y_train_balanced_labels, class_weights = \
        apply_hybrid_balancing_to_fold(X_train_fold_paths, y_train_fold_labels, class_names)

    print(f"  Train samples AFTER balancing (undersampled): {len(X_train_balanced_paths)}")
    print(f"  Balanced Train labels distribution: {np.bincount(y_train_balanced_labels)}")
    print(f"  Class Weights for training: {class_weights}")


    # Create tf.data.Dataset for training and validation
    # Training Dataset: Load, Augment, Shuffle, Batch, Prefetch
    train_ds = tf.data.Dataset.from_tensor_slices((X_train_balanced_paths, y_train_balanced_labels))
    train_ds = train_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE) # Apply augmentation
    train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    # Validation Dataset: Load, Batch, Prefetch (no augmentation for validation)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val_fold_paths, y_val_fold_labels))
    val_ds = val_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    # Build and compile a fresh model for each fold
    model = build_inceptionv3_model()

    # Callbacks
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True), # Increased patience
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=0.00001, verbose=1) # Increased patience
    ]

    # Train the model
    print("  Training model...")
    history = model.fit(train_ds,
                        epochs=100, # Max epochs, EarlyStopping will stop it
                        validation_data=val_ds,
                        class_weight=class_weights, # Apply class weights during training
                        callbacks=callbacks,
                        verbose=1)

    # Evaluate the model on the validation data for the current fold
    print("  Evaluating model on validation set...")
    y_true_val = []
    y_pred_proba_val = []

    # Iterate through the validation dataset to collect true labels and predictions
    # Use tqdm for progress bar if validation set is large
    for images, labels_one_hot in tqdm(val_ds, desc="Predicting on validation set"):
        y_true_val.extend(np.argmax(labels_one_hot.numpy(), axis=1))
        y_pred_proba_val.extend(model.predict(images))

    y_pred_val = np.argmax(np.array(y_pred_proba_val), axis=1)

    # Calculate overall metrics for the current fold
    fold_accuracy = accuracy_score(y_true_val, y_pred_val)

    # Get detailed per-class metrics using classification_report
    report = classification_report(y_true_val, y_pred_val, target_names=class_names, output_dict=True, zero_division=0)

    # Determine the minority class from the initial data distribution
    minority_class_label_idx = np.bincount(labels).argmin()
    minority_class_name = class_names[minority_class_label_idx]

    minority_precision = report[minority_class_name]['precision']
    minority_recall = report[minority_class_name]['recall']
    minority_f1 = report[minority_class_name]['f1-score']

    print(f"Fold {fold_idx + 1} Metrics:")
    print(f"  Overall Accuracy: {fold_accuracy:.4f}")
    print(f"  Minority Class ({minority_class_name}):")
    print(f"    Precision: {minority_precision:.4f}")
    print(f"    Recall: {minority_recall:.4f}")
    print(f"    F1-score: {minority_f1:.4f}")
    print("  Full Classification Report:\n", classification_report(y_true_val, y_pred_val, target_names=class_names, zero_division=0))

    fold_results.append({
        'overall_accuracy': fold_accuracy,
        'minority_precision': minority_precision,
        'minority_recall': minority_recall,
        'minority_f1': minority_f1
    })

    # Clear session to free up memory before next fold
    tf.keras.backend.clear_session()
    del model # Delete model instance to release resources

# ----------------------------------------------------------------------
# Step 6: Aggregate and Report Final Results
# ----------------------------------------------------------------------
print("\n--- K-Fold Cross-Validation Final Results ---")
avg_overall_accuracy = np.mean([res['overall_accuracy'] for res in fold_results])
std_overall_accuracy = np.std([res['overall_accuracy'] for res in fold_results])

avg_minority_precision = np.mean([res['minority_precision'] for res in fold_results])
std_minority_precision = np.std([res['minority_precision'] for res in fold_results])

avg_minority_recall = np.mean([res['minority_recall'] for res in fold_results])
std_minority_recall = np.std([res['minority_recall'] for res in fold_results])

avg_minority_f1 = np.mean([res['minority_f1'] for res in fold_results])
std_minority_f1 = np.std([res['minority_f1'] for res in fold_results])

print(f"Average Overall Accuracy: {avg_overall_accuracy:.4f} +/- {std_overall_accuracy:.4f}")
print(f"Average Minority Precision: {avg_minority_precision:.4f} +/- {std_minority_precision:.4f}")
print(f"Average Minority Recall: {avg_minority_recall:.4f} +/- {std_minority_recall:.4f}")
print(f"Average Minority F1-score: {avg_minority_f1:.4f} +/- {std_minority_f1:.4f}")
# Out:
# Num GPUs Available:  1
# Mounted at /content/drive
# Detected classes: ['Arctocephalus_galapagoensis', 'Zalophus_wollebaeki']
#
# Total number of samples loaded for K-fold: 336
# Initial Class distribution: [ 45 291]
#
# --- Starting Fold 1/5 ---
#   Train samples in fold: 268
#   Validation samples in fold: 68
#   Train labels distribution (before balancing): [ 36 232]
#   Val labels distribution: [ 9 59]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 209s 15s/step - accuracy: 0.4106 - loss: 1.0694 - val_accuracy: 0.1471 - val_loss: 2.6856 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - accuracy: 0.5655 - loss: 1.1505 - val_accuracy: 0.9118 - val_loss: 0.2295 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - accuracy: 0.6662 - loss: 0.6032 - val_accuracy: 0.7647 - val_loss: 0.4174 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 399ms/step - accuracy: 0.8837 - loss: 0.2745 - val_accuracy: 0.3824 - val_loss: 1.2200 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - accuracy: 0.8416 - loss: 0.3824 - val_accuracy: 0.7941 - val_loss: 0.3516 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 475ms/step - accuracy: 0.9440 - loss: 0.1463 - val_accuracy: 0.9706 - val_loss: 0.1375 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 0.9705 - loss: 0.1628 - val_accuracy: 0.9265 - val_loss: 0.2254 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 732ms/step - accuracy: 0.9891 - loss: 0.0925 - val_accuracy: 0.7647 - val_loss: 0.4723 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 406ms/step - accuracy: 0.9596 - loss: 0.0950 - val_accuracy: 0.8088 - val_loss: 0.3862 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - accuracy: 0.9813 - loss: 0.0627 - val_accuracy: 0.9265 - val_loss: 0.1960 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - accuracy: 1.0000 - loss: 0.0514 - val_accuracy: 0.9265 - val_loss: 0.1729 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - accuracy: 1.0000 - loss: 0.0486 - val_accuracy: 0.8971 - val_loss: 0.2302 - learning_rate: 0.0010
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0336
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.8382 - val_loss: 0.3240 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 506ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.8382 - val_loss: 0.3415 - learning_rate: 2.0000e-04
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.8382 - val_loss: 0.3391 - learning_rate: 2.0000e-04
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.8676 - val_loss: 0.3189 - learning_rate: 2.0000e-04
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.8676 - val_loss: 0.2991 - learning_rate: 2.0000e-04
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.8676 - val_loss: 0.2914 - learning_rate: 2.0000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.8676 - val_loss: 0.2867 - learning_rate: 2.0000e-04
# Epoch 20/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0198
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 721ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.8676 - val_loss: 0.2861 - learning_rate: 2.0000e-04
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.8676 - val_loss: 0.2851 - learning_rate: 4.0000e-05
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Fold 1 Metrics:
#   Overall Accuracy: 0.9706
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.8182
#     Recall: 1.0000
#     F1-score: 0.9000
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.82      1.00      0.90         9
#         Zalophus_wollebaeki       1.00      0.97      0.98        59
#
#                    accuracy                           0.97        68
#                   macro avg       0.91      0.98      0.94        68
#                weighted avg       0.98      0.97      0.97        68
#
#
# --- Starting Fold 2/5 ---
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 11s/step - accuracy: 0.6215 - loss: 0.5925 - val_accuracy: 0.8657 - val_loss: 0.3445 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 418ms/step - accuracy: 0.7396 - loss: 0.6072 - val_accuracy: 0.2687 - val_loss: 1.7875 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 820ms/step - accuracy: 0.7257 - loss: 0.5908 - val_accuracy: 0.9254 - val_loss: 0.1452 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - accuracy: 0.9301 - loss: 0.1892 - val_accuracy: 0.9701 - val_loss: 0.1691 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.9891 - loss: 0.0638 - val_accuracy: 0.8955 - val_loss: 0.3332 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 445ms/step - accuracy: 0.9891 - loss: 0.0610 - val_accuracy: 0.9701 - val_loss: 0.1428 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 477ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.9552 - val_loss: 0.0871 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 1.0000 - loss: 0.0506 - val_accuracy: 0.9552 - val_loss: 0.0865 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 745ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.9254 - val_loss: 0.2101 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 399ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.8806 - val_loss: 0.3171 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 0.8955 - val_loss: 0.2386 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 398ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9701 - val_loss: 0.1390 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 406ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9552 - val_loss: 0.0932 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 491ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9552 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9701 - val_loss: 0.1001 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9701 - val_loss: 0.1322 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9403 - val_loss: 0.1742 - learning_rate: 0.0010
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9254 - val_loss: 0.2018 - learning_rate: 0.0010
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9254 - val_loss: 0.2114 - learning_rate: 0.0010
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 515ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9254 - val_loss: 0.1954 - learning_rate: 0.0010
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9254 - val_loss: 0.1734 - learning_rate: 0.0010
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 352ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9403 - val_loss: 0.1682 - learning_rate: 2.0000e-04
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9552 - val_loss: 0.1636 - learning_rate: 2.0000e-04
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9552 - val_loss: 0.1590 - learning_rate: 2.0000e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9552 - val_loss: 0.1564 - learning_rate: 2.0000e-04
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 493ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9552 - val_loss: 0.1548 - learning_rate: 2.0000e-04
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 401ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9552 - val_loss: 0.1540 - learning_rate: 2.0000e-04
# Epoch 28/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9552 - val_loss: 0.1541 - learning_rate: 2.0000e-04
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9552 - val_loss: 0.1542 - learning_rate: 4.0000e-05
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Fold 2 Metrics:
#   Overall Accuracy: 0.9552
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.8000
#     Recall: 0.8889
#     F1-score: 0.8421
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.80      0.89      0.84         9
#         Zalophus_wollebaeki       0.98      0.97      0.97        58
#
#                    accuracy                           0.96        67
#                   macro avg       0.89      0.93      0.91        67
#                weighted avg       0.96      0.96      0.96        67
#
#
# --- Starting Fold 3/5 ---
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 34s 10s/step - accuracy: 0.5521 - loss: 0.9848 - val_accuracy: 0.8955 - val_loss: 0.1924 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 15s 368ms/step - accuracy: 0.8181 - loss: 0.3765 - val_accuracy: 0.5522 - val_loss: 0.8375 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 439ms/step - accuracy: 0.8850 - loss: 0.2451 - val_accuracy: 0.9403 - val_loss: 0.1773 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 476ms/step - accuracy: 0.8641 - loss: 0.2884 - val_accuracy: 0.9552 - val_loss: 0.1404 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 0.9891 - loss: 0.0892 - val_accuracy: 0.8209 - val_loss: 0.4088 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.9518 - loss: 0.1383 - val_accuracy: 0.8955 - val_loss: 0.2104 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 447ms/step - accuracy: 0.9891 - loss: 0.0518 - val_accuracy: 0.9552 - val_loss: 0.1225 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 486ms/step - accuracy: 1.0000 - loss: 0.0484 - val_accuracy: 0.9552 - val_loss: 0.1159 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - accuracy: 1.0000 - loss: 0.0375 - val_accuracy: 0.9552 - val_loss: 0.1326 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9104 - val_loss: 0.1629 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 0.9813 - loss: 0.0389 - val_accuracy: 0.9403 - val_loss: 0.1255 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 437ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9403 - val_loss: 0.1142 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 846ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.9403 - val_loss: 0.1092 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9552 - val_loss: 0.0976 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9403 - val_loss: 0.1041 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9403 - val_loss: 0.1196 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9552 - val_loss: 0.1336 - learning_rate: 0.0010
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9552 - val_loss: 0.1381 - learning_rate: 0.0010
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 513ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9552 - val_loss: 0.1381 - learning_rate: 0.0010
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9552 - val_loss: 0.1327 - learning_rate: 0.0010
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 399ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9552 - val_loss: 0.1269 - learning_rate: 0.0010
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9552 - val_loss: 0.1251 - learning_rate: 2.0000e-04
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9552 - val_loss: 0.1257 - learning_rate: 2.0000e-04
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9552 - val_loss: 0.1261 - learning_rate: 2.0000e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9552 - val_loss: 0.1270 - learning_rate: 2.0000e-04
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9552 - val_loss: 0.1273 - learning_rate: 2.0000e-04
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9552 - val_loss: 0.1277 - learning_rate: 2.0000e-04
# Epoch 28/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9552 - val_loss: 0.1280 - learning_rate: 2.0000e-04
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9552 - val_loss: 0.1281 - learning_rate: 4.0000e-05
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f776eb53f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f776eb53f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Fold 3 Metrics:
#   Overall Accuracy: 0.9552
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.8000
#     Recall: 0.8889
#     F1-score: 0.8421
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.80      0.89      0.84         9
#         Zalophus_wollebaeki       0.98      0.97      0.97        58
#
#                    accuracy                           0.96        67
#                   macro avg       0.89      0.93      0.91        67
#                weighted avg       0.96      0.96      0.96        67
#
#
# --- Starting Fold 4/5 ---
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 14s/step - accuracy: 0.3906 - loss: 2.3183 - val_accuracy: 0.2985 - val_loss: 0.8624 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 356ms/step - accuracy: 0.5590 - loss: 0.8973 - val_accuracy: 0.1343 - val_loss: 1.9033 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - accuracy: 0.5247 - loss: 0.8880 - val_accuracy: 0.9254 - val_loss: 0.3967 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 820ms/step - accuracy: 0.7652 - loss: 0.4722 - val_accuracy: 0.8657 - val_loss: 0.2976 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.6766 - loss: 0.4799 - val_accuracy: 0.8657 - val_loss: 0.4803 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.8828 - loss: 0.3546 - val_accuracy: 0.8060 - val_loss: 0.5004 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - accuracy: 0.9332 - loss: 0.2808 - val_accuracy: 0.9254 - val_loss: 0.2473 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - accuracy: 0.9891 - loss: 0.2190 - val_accuracy: 0.9403 - val_loss: 0.2288 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 0.9714 - loss: 0.1732 - val_accuracy: 0.9104 - val_loss: 0.2893 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 838ms/step - accuracy: 0.9596 - loss: 0.1472 - val_accuracy: 0.9403 - val_loss: 0.2230 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - accuracy: 1.0000 - loss: 0.1194 - val_accuracy: 0.9403 - val_loss: 0.1883 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 1.0000 - loss: 0.1006 - val_accuracy: 0.9403 - val_loss: 0.1925 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 1.0000 - loss: 0.0700 - val_accuracy: 0.9254 - val_loss: 0.2196 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 727ms/step - accuracy: 0.9891 - loss: 0.0686 - val_accuracy: 0.9403 - val_loss: 0.1987 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 425ms/step - accuracy: 1.0000 - loss: 0.0570 - val_accuracy: 0.9403 - val_loss: 0.1803 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 423ms/step - accuracy: 1.0000 - loss: 0.0463 - val_accuracy: 0.9403 - val_loss: 0.1789 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 0.9403 - val_loss: 0.1889 - learning_rate: 0.0010
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.9403 - val_loss: 0.1852 - learning_rate: 0.0010
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.9403 - val_loss: 0.1808 - learning_rate: 0.0010
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.9403 - val_loss: 0.1841 - learning_rate: 0.0010
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.9254 - val_loss: 0.1982 - learning_rate: 0.0010
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.9254 - val_loss: 0.2036 - learning_rate: 0.0010
# Epoch 23/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.9403 - val_loss: 0.1924 - learning_rate: 0.0010
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9403 - val_loss: 0.1904 - learning_rate: 2.0000e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.9403 - val_loss: 0.1889 - learning_rate: 2.0000e-04
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9403 - val_loss: 0.1876 - learning_rate: 2.0000e-04
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.9403 - val_loss: 0.1875 - learning_rate: 2.0000e-04
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9403 - val_loss: 0.1879 - learning_rate: 2.0000e-04
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.9403 - val_loss: 0.1884 - learning_rate: 2.0000e-04
# Epoch 30/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 404ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9403 - val_loss: 0.1883 - learning_rate: 2.0000e-04
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.9403 - val_loss: 0.1884 - learning_rate: 4.0000e-05
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Fold 4 Metrics:
#   Overall Accuracy: 0.9403
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.7778
#     Recall: 0.7778
#     F1-score: 0.7778
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.78      0.78      0.78         9
#         Zalophus_wollebaeki       0.97      0.97      0.97        58
#
#                    accuracy                           0.94        67
#                   macro avg       0.87      0.87      0.87        67
#                weighted avg       0.94      0.94      0.94        67
#
#
# --- Starting Fold 5/5 ---
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 9s/step - accuracy: 0.4705 - loss: 1.7375 - val_accuracy: 0.2537 - val_loss: 1.1811 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 470ms/step - accuracy: 0.6141 - loss: 0.7049 - val_accuracy: 0.4478 - val_loss: 0.9024 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 484ms/step - accuracy: 0.8663 - loss: 0.3690 - val_accuracy: 0.8657 - val_loss: 0.2572 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 741ms/step - accuracy: 0.7886 - loss: 0.4008 - val_accuracy: 0.8060 - val_loss: 0.4550 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.9084 - loss: 0.2469 - val_accuracy: 0.7612 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 487ms/step - accuracy: 0.9449 - loss: 0.1834 - val_accuracy: 0.9403 - val_loss: 0.2091 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 477ms/step - accuracy: 0.9674 - loss: 0.1506 - val_accuracy: 0.9403 - val_loss: 0.2064 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - accuracy: 0.9931 - loss: 0.1009 - val_accuracy: 0.8209 - val_loss: 0.4175 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.9705 - loss: 0.1008 - val_accuracy: 0.8507 - val_loss: 0.2731 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 468ms/step - accuracy: 1.0000 - loss: 0.0565 - val_accuracy: 0.9254 - val_loss: 0.1646 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 740ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 0.9254 - val_loss: 0.1765 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step - accuracy: 1.0000 - loss: 0.0433 - val_accuracy: 0.8507 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.8507 - val_loss: 0.4231 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - accuracy: 1.0000 - loss: 0.0407 - val_accuracy: 0.8507 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.8806 - val_loss: 0.2180 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.8955 - val_loss: 0.1850 - learning_rate: 0.0010
# Epoch 17/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 723ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.8806 - val_loss: 0.2077 - learning_rate: 0.0010
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 394ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8806 - val_loss: 0.2177 - learning_rate: 2.0000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.8806 - val_loss: 0.2318 - learning_rate: 2.0000e-04
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.8507 - val_loss: 0.2493 - learning_rate: 2.0000e-04
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8507 - val_loss: 0.2679 - learning_rate: 2.0000e-04
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.8657 - val_loss: 0.2855 - learning_rate: 2.0000e-04
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8657 - val_loss: 0.2938 - learning_rate: 2.0000e-04
# Epoch 24/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 502ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.8657 - val_loss: 0.2950 - learning_rate: 2.0000e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 414ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8657 - val_loss: 0.2929 - learning_rate: 4.0000e-05
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Fold 5 Metrics:
#   Overall Accuracy: 0.9254
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.7500
#     Recall: 0.6667
#     F1-score: 0.7059
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.75      0.67      0.71         9
#         Zalophus_wollebaeki       0.95      0.97      0.96        58
#
#                    accuracy                           0.93        67
#                   macro avg       0.85      0.82      0.83        67
#                weighted avg       0.92      0.93      0.92        67
#
#
# --- K-Fold Cross-Validation Final Results ---
# Average Overall Accuracy: 0.9493 +/- 0.0153
# Average Minority Precision: 0.7892 +/- 0.0234
# Average Minority Recall: 0.8444 +/- 0.1133
# Average Minority F1-score: 0.8136 +/- 0.0663

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix # Added confusion_matrix
import os
import cv2
from tqdm.notebook import tqdm
import pandas as pd
import json

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Ensure you have a GPU available for faster training
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
if not tf.config.experimental.list_physical_devices('GPU'):
    print("WARNING: No GPU found. Training will be extremely slow on CPU. Please enable GPU runtime: Runtime -> Change runtime type -> GPU.")

# ----------------------------------------------------------------------
# Step 1: Mount Google Drive (if not already mounted)
# ----------------------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive')

# ----------------------------------------------------------------------
# Step 2: Load and Prepare Your Full Dataset
# ----------------------------------------------------------------------
# --- IMPORTANT: This path should point to your combined dataset folder ---
data_dir = '/content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/combined_dataset_for_kfold'

image_paths = []
labels = []

class_names = sorted(os.listdir(data_dir))
class_to_idx = {name: i for i, name in enumerate(class_names)}

print(f"Detected classes: {class_names}")

for class_name in class_names:
    class_path = os.path.join(data_dir, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            if os.path.isfile(img_path):
                image_paths.append(img_path)
                labels.append(class_to_idx[class_name])
    else:
        print(f"Warning: '{class_path}' is not a directory. Skipping.")

image_paths = np.array(image_paths)
labels = np.array(labels)

print(f"\nTotal number of samples loaded for K-fold: {len(image_paths)}")
print(f"Initial Class distribution: {np.bincount(labels)}")

# Define input shape for InceptionV3
IMG_HEIGHT, IMG_WIDTH = 299, 299
NUM_CLASSES = len(class_names)
BATCH_SIZE = 32

# Data preprocessing function
def load_and_preprocess_image(image_path, label, img_size=(IMG_HEIGHT, IMG_WIDTH)):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, img_size)
    img = preprocess_input(img)
    label = tf.one_hot(label, NUM_CLASSES)
    return img, label

# Data augmentation function
def augment_image(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, label

# ----------------------------------------------------------------------
# Step 3: Define Your Model Building Function
# ----------------------------------------------------------------------
def build_inceptionv3_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# ----------------------------------------------------------------------
# Step 4: Implement Your Hybrid Balancing Strategy (within the fold)
# ----------------------------------------------------------------------
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils import class_weight

def apply_hybrid_balancing_to_fold(X_train_paths, y_train_labels, class_names):
    indices = np.arange(len(X_train_paths)).reshape(-1, 1)
    rus = RandomUnderSampler(sampling_strategy='majority', random_state=42)
    resampled_indices_dummy, y_resampled_labels = rus.fit_resample(indices, y_train_labels)
    X_resampled_paths = X_train_paths[resampled_indices_dummy.flatten()]

    unique_classes = np.unique(y_resampled_labels)
    weights = class_weight.compute_class_weight(class_weight='balanced',
                                                classes=np.array(range(len(class_names))),
                                                y=y_resampled_labels)
    class_weights_dict = dict(zip(range(len(class_names)), weights))

    return X_resampled_paths, y_resampled_labels, class_weights_dict

# ----------------------------------------------------------------------
# Define where to save K-fold results
# This will create a 'kfold_results' folder inside 'my_galapagos_seals_dataset'
# ----------------------------------------------------------------------
kfold_results_base_dir = os.path.join(os.path.dirname(data_dir), 'kfold_results')
os.makedirs(kfold_results_base_dir, exist_ok=True)
print(f"\nK-fold results will be saved in: {kfold_results_base_dir}")

# ----------------------------------------------------------------------
# Step 5: K-Fold Cross-Validation Loop (MODIFIED for saving results & CM)
# ----------------------------------------------------------------------
N_SPLITS = 5
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)

fold_results = []
all_confusion_matrices = [] # List to store confusion matrix for each fold

for fold_idx, (train_index, val_index) in enumerate(skf.split(image_paths, labels)):
    print(f"\n--- Starting Fold {fold_idx + 1}/{N_SPLITS} ---")

    # Define and create directory for current fold's results
    current_fold_dir = os.path.join(kfold_results_base_dir, f'fold_{fold_idx}')
    os.makedirs(current_fold_dir, exist_ok=True)
    print(f"  Results for Fold {fold_idx + 1} will be saved in: {current_fold_dir}")

    # Split data for the current fold
    X_train_fold_paths, X_val_fold_paths = image_paths[train_index], image_paths[val_index]
    y_train_fold_labels, y_val_fold_labels = labels[train_index], labels[val_index]

    print(f"  Train samples in fold: {len(X_train_fold_paths)}")
    print(f"  Validation samples in fold: {len(X_val_fold_paths)}")
    print(f"  Train labels distribution (before balancing): {np.bincount(y_train_fold_labels)}")
    print(f"  Val labels distribution: {np.bincount(y_val_fold_labels)}")

    # Apply Hybrid Balancing ONLY to the training data of the current fold
    X_train_balanced_paths, y_train_balanced_labels, class_weights = \
        apply_hybrid_balancing_to_fold(X_train_fold_paths, y_train_fold_labels, class_names)

    print(f"  Train samples AFTER balancing (undersampled): {len(X_train_balanced_paths)}")
    print(f"  Balanced Train labels distribution: {np.bincount(y_train_balanced_labels)}")
    print(f"  Class Weights for training: {class_weights}")

    # Create tf.data.Dataset for training and validation
    train_ds = tf.data.Dataset.from_tensor_slices((X_train_balanced_paths, y_train_balanced_labels))
    train_ds = train_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_ds = tf.data.Dataset.from_tensor_slices((X_val_fold_paths, y_val_fold_labels))
    val_ds = val_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    # Build and compile a fresh model for each fold
    model = build_inceptionv3_model()

    # Callbacks (with ModelCheckpoint added)
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(current_fold_dir, 'best_model.h5'),
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=0.00001, verbose=1),
        model_checkpoint_callback
    ]

    # Train the model
    print("  Training model...")
    history = model.fit(train_ds,
                        epochs=100,
                        validation_data=val_ds,
                        class_weight=class_weights,
                        callbacks=callbacks,
                        verbose=1)

    # Save training history for the current fold
    history_df = pd.DataFrame(history.history)
    history_df.to_csv(os.path.join(current_fold_dir, 'training_history.csv'), index=False)
    print(f"  Saved training history for Fold {fold_idx + 1}.")

    # Evaluate the model on the validation data for the current fold
    print("  Evaluating model on validation set...")
    y_true_val = []
    y_pred_proba_val = []

    for images, labels_one_hot in tqdm(val_ds, desc="Predicting on validation set"):
        y_true_val.extend(np.argmax(labels_one_hot.numpy(), axis=1))
        y_pred_proba_val.extend(model.predict(images))

    y_pred_val = np.argmax(np.array(y_pred_proba_val), axis=1)

    # Calculate metrics for the current fold
    fold_accuracy = accuracy_score(y_true_val, y_pred_val)
    report = classification_report(y_true_val, y_pred_val, target_names=class_names, output_dict=True, zero_division=0)

    # Calculate Confusion Matrix for the current fold
    cm = confusion_matrix(y_true_val, y_pred_val)
    all_confusion_matrices.append(cm) # Store for averaging later

    print(f"\nFold {fold_idx + 1} Metrics:")
    print(f"  Overall Accuracy: {fold_accuracy:.4f}")

    minority_class_label_idx = np.bincount(labels).argmin()
    minority_class_name = class_names[minority_class_label_idx]

    minority_precision = report[minority_class_name]['precision']
    minority_recall = report[minority_class_name]['recall']
    minority_f1 = report[minority_class_name]['f1-score']

    print(f"  Minority Class ({minority_class_name}):")
    print(f"    Precision: {minority_precision:.4f}")
    print(f"    Recall: {minority_recall:.4f}")
    print(f"    F1-score: {minority_f1:.4f}")
    print("  Full Classification Report:\n", classification_report(y_true_val, y_pred_val, target_names=class_names, zero_division=0))

    # Print Confusion Matrix for the current fold (formatted with pandas for clarity)
    print("\n  Confusion Matrix for Fold {}:".format(fold_idx + 1))
    cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
    print(cm_df)

    # Save Confusion Matrix for the current fold
    cm_filepath = os.path.join(current_fold_dir, 'confusion_matrix.csv')
    cm_df.to_csv(cm_filepath)
    print(f"  Confusion Matrix saved to: {cm_filepath}")

    fold_results.append({
        'overall_accuracy': fold_accuracy,
        'minority_precision': minority_precision,
        'minority_recall': minority_recall,
        'minority_f1': minority_f1,
        'confusion_matrix': cm.tolist() # Convert numpy array to list for JSON compatibility
    })

    tf.keras.backend.clear_session()
    del model

# ----------------------------------------------------------------------
# Step 6: Aggregate and Report Final Results (MODIFIED to include Average CM)
# ----------------------------------------------------------------------
print("\n--- K-Fold Cross-Validation Final Results ---")
avg_overall_accuracy = np.mean([res['overall_accuracy'] for res in fold_results])
std_overall_accuracy = np.std([res['overall_accuracy'] for res in fold_results])

avg_minority_precision = np.mean([res['minority_precision'] for res in fold_results])
std_minority_precision = np.std([res['minority_precision'] for res in fold_results])

avg_minority_recall = np.mean([res['minority_recall'] for res in fold_results])
std_minority_recall = np.std([res['minority_recall'] for res in fold_results])

avg_minority_f1 = np.mean([res['minority_f1'] for res in fold_results])
std_minority_f1 = np.std([res['minority_f1'] for res in fold_results])

# Calculate and display Average Confusion Matrix
# np.array(all_confusion_matrices) converts list of CMs to a 3D numpy array
# axis=0 means average across the first dimension (the folds)
average_cm = np.mean(np.array(all_confusion_matrices), axis=0)
print("\n--- Average Confusion Matrix across all Folds (Rounded to 2 decimal places) ---")
average_cm_df = pd.DataFrame(average_cm, index=class_names, columns=class_names)
print(average_cm_df.round(2)) # Round for cleaner display of averages

final_summary = {
    "Average Overall Accuracy": f"{avg_overall_accuracy:.4f} +/- {std_overall_accuracy:.4f}",
    "Average Minority Precision": f"{avg_minority_precision:.4f} +/- {std_minority_precision:.4f}",
    "Average Minority Recall": f"{avg_minority_recall:.4f} +/- {std_minority_recall:.4f}",
    "Average Minority F1-score": f"{avg_minority_f1:.4f} +/- {std_minority_f1:.4f}",
    "Average Confusion Matrix (rows are true, columns are predicted)": average_cm.round(2).tolist()
}

print(json.dumps(final_summary, indent=4))

# Save the final summary to a text file (JSON format for readability)
summary_filepath = os.path.join(kfold_results_base_dir, 'kfold_summary_metrics.json')
with open(summary_filepath, 'w') as f:
    json.dump(final_summary, f, indent=4)
print(f"\nFinal K-fold summary metrics and average CM saved to: {summary_filepath}")
# Out:
# Num GPUs Available:  1
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Detected classes: ['Arctocephalus_galapagoensis', 'Zalophus_wollebaeki']
#
# Total number of samples loaded for K-fold: 336
# Initial Class distribution: [ 45 291]
#
# K-fold results will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results
#
# --- Starting Fold 1/5 ---
#   Results for Fold 1 will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_0
#   Train samples in fold: 268
#   Validation samples in fold: 68
#   Train labels distribution (before balancing): [ 36 232]
#   Val labels distribution: [ 9 59]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5503 - loss: 1.2127
# Epoch 1: val_loss improved from inf to 2.55570, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 9s/step - accuracy: 0.5482 - loss: 1.2630 - val_accuracy: 0.1618 - val_loss: 2.5557 - learning_rate: 0.0010
# Epoch 2/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4766 - loss: 1.3043
# Epoch 2: val_loss improved from 2.55570 to 0.22197, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 858ms/step - accuracy: 0.5438 - loss: 1.1186 - val_accuracy: 0.9412 - val_loss: 0.2220 - learning_rate: 0.0010
# Epoch 3/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7734 - loss: 0.3818
# Epoch 3: val_loss did not improve from 0.22197
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 411ms/step - accuracy: 0.7478 - loss: 0.4058 - val_accuracy: 0.7941 - val_loss: 0.3833 - learning_rate: 0.0010
# Epoch 4/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8984 - loss: 0.2296
# Epoch 4: val_loss did not improve from 0.22197
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 467ms/step - accuracy: 0.8867 - loss: 0.2436 - val_accuracy: 0.5294 - val_loss: 1.0411 - learning_rate: 0.0010
# Epoch 5/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8516 - loss: 0.2969
# Epoch 5: val_loss did not improve from 0.22197
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.8633 - loss: 0.2904 - val_accuracy: 0.8235 - val_loss: 0.2966 - learning_rate: 0.0010
# Epoch 6/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9766 - loss: 0.1357
# Epoch 6: val_loss improved from 0.22197 to 0.14960, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.9813 - loss: 0.1340 - val_accuracy: 0.9412 - val_loss: 0.1496 - learning_rate: 0.0010
# Epoch 7/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9766 - loss: 0.1302
# Epoch 7: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 414ms/step - accuracy: 0.9813 - loss: 0.1322 - val_accuracy: 0.8382 - val_loss: 0.2558 - learning_rate: 0.0010
# Epoch 8/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9922 - loss: 0.0836
# Epoch 8: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.9891 - loss: 0.0808 - val_accuracy: 0.8088 - val_loss: 0.4343 - learning_rate: 0.0010
# Epoch 9/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9766 - loss: 0.0774
# Epoch 9: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 412ms/step - accuracy: 0.9813 - loss: 0.0748 - val_accuracy: 0.8235 - val_loss: 0.3512 - learning_rate: 0.0010
# Epoch 10/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9766 - loss: 0.0528
# Epoch 10: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - accuracy: 0.9813 - loss: 0.0524 - val_accuracy: 0.8971 - val_loss: 0.2080 - learning_rate: 0.0010
# Epoch 11/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0468
# Epoch 11: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 409ms/step - accuracy: 1.0000 - loss: 0.0461 - val_accuracy: 0.8824 - val_loss: 0.2167 - learning_rate: 0.0010
# Epoch 12/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 12: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 0.0389 - val_accuracy: 0.8676 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 13: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 1.0000 - loss: 0.0293 - val_accuracy: 0.8235 - val_loss: 0.3322 - learning_rate: 0.0010
# Epoch 14/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 14: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 727ms/step - accuracy: 1.0000 - loss: 0.0232 - val_accuracy: 0.8235 - val_loss: 0.3429 - learning_rate: 2.0000e-04
# Epoch 15/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 15: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 404ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 0.8235 - val_loss: 0.3349 - learning_rate: 2.0000e-04
# Epoch 16/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0231
# Epoch 16: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.8235 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 17/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 17: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.8382 - val_loss: 0.2963 - learning_rate: 2.0000e-04
# Epoch 18/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 18: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 411ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.8382 - val_loss: 0.2957 - learning_rate: 2.0000e-04
# Epoch 19/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 19: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.8382 - val_loss: 0.2998 - learning_rate: 2.0000e-04
# Epoch 20/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0217
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 20: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.8382 - val_loss: 0.3024 - learning_rate: 2.0000e-04
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 21: val_loss did not improve from 0.14960
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8382 - val_loss: 0.3024 - learning_rate: 4.0000e-05
#   Saved training history for Fold 1.
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#
# Fold 1 Metrics:
#   Overall Accuracy: 0.9412
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.7273
#     Recall: 0.8889
#     F1-score: 0.8000
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.73      0.89      0.80         9
#         Zalophus_wollebaeki       0.98      0.95      0.97        59
#
#                    accuracy                           0.94        68
#                   macro avg       0.85      0.92      0.88        68
#                weighted avg       0.95      0.94      0.94        68
#
#
#   Confusion Matrix for Fold 1:
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                            8                    1
# Zalophus_wollebaeki                                    3                   56
#   Confusion Matrix saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_0/confusion_matrix.csv
#
# --- Starting Fold 2/5 ---
#   Results for Fold 2 will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5104 - loss: 0.9376
# Epoch 1: val_loss improved from inf to 1.59485, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 9s/step - accuracy: 0.5078 - loss: 0.9672 - val_accuracy: 0.2836 - val_loss: 1.5948 - learning_rate: 0.0010
# Epoch 2/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6172 - loss: 0.7953
# Epoch 2: val_loss improved from 1.59485 to 0.21916, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6419 - loss: 0.7307 - val_accuracy: 0.8806 - val_loss: 0.2192 - learning_rate: 0.0010
# Epoch 3/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8125 - loss: 0.3523
# Epoch 3: val_loss did not improve from 0.21916
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - accuracy: 0.8368 - loss: 0.3302 - val_accuracy: 0.7164 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 4/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8828 - loss: 0.2765
# Epoch 4: val_loss did not improve from 0.21916
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.8581 - loss: 0.3306 - val_accuracy: 0.8507 - val_loss: 0.3391 - learning_rate: 0.0010
# Epoch 5/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9688 - loss: 0.1175
# Epoch 5: val_loss improved from 0.21916 to 0.15904, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 864ms/step - accuracy: 0.9705 - loss: 0.1198 - val_accuracy: 0.9403 - val_loss: 0.1590 - learning_rate: 0.0010
# Epoch 6/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8438 - loss: 0.3545
# Epoch 6: val_loss improved from 0.15904 to 0.11521, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 993ms/step - accuracy: 0.8594 - loss: 0.3198 - val_accuracy: 0.9552 - val_loss: 0.1152 - learning_rate: 0.0010
# Epoch 7/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9531 - loss: 0.1274
# Epoch 7: val_loss did not improve from 0.11521
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - accuracy: 0.9627 - loss: 0.1180 - val_accuracy: 0.8657 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 8/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9766 - loss: 0.1066
# Epoch 8: val_loss did not improve from 0.11521
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - accuracy: 0.9744 - loss: 0.1036 - val_accuracy: 0.9104 - val_loss: 0.2538 - learning_rate: 0.0010
# Epoch 9/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9688 - loss: 0.0667
# Epoch 9: val_loss did not improve from 0.11521
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - accuracy: 0.9705 - loss: 0.0690 - val_accuracy: 0.9552 - val_loss: 0.1255 - learning_rate: 0.0010
# Epoch 10/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9766 - loss: 0.0582
# Epoch 10: val_loss improved from 0.11521 to 0.09735, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.9813 - loss: 0.0530 - val_accuracy: 0.9552 - val_loss: 0.0973 - learning_rate: 0.0010
# Epoch 11/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0534
# Epoch 11: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 741ms/step - accuracy: 1.0000 - loss: 0.0524 - val_accuracy: 0.9552 - val_loss: 0.1008 - learning_rate: 0.0010
# Epoch 12/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0374
# Epoch 12: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.9552 - val_loss: 0.1298 - learning_rate: 0.0010
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9766 - loss: 0.0354
# Epoch 13: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 398ms/step - accuracy: 0.9813 - loss: 0.0326 - val_accuracy: 0.9552 - val_loss: 0.1709 - learning_rate: 0.0010
# Epoch 14/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9922 - loss: 0.0218
# Epoch 14: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 400ms/step - accuracy: 0.9891 - loss: 0.0257 - val_accuracy: 0.9552 - val_loss: 0.1952 - learning_rate: 0.0010
# Epoch 15/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9766 - loss: 0.0347
# Epoch 15: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 788ms/step - accuracy: 0.9813 - loss: 0.0305 - val_accuracy: 0.9552 - val_loss: 0.1446 - learning_rate: 0.0010
# Epoch 16/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 16: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 721ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9552 - val_loss: 0.1154 - learning_rate: 0.0010
# Epoch 17/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 17: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.9552 - val_loss: 0.1067 - learning_rate: 0.0010
# Epoch 18/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 18: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 404ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9552 - val_loss: 0.1072 - learning_rate: 2.0000e-04
# Epoch 19/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 19: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9552 - val_loss: 0.1105 - learning_rate: 2.0000e-04
# Epoch 20/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 20: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9552 - val_loss: 0.1166 - learning_rate: 2.0000e-04
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 21: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9552 - val_loss: 0.1248 - learning_rate: 2.0000e-04
# Epoch 22/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 22: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 731ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9552 - val_loss: 0.1333 - learning_rate: 2.0000e-04
# Epoch 23/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 23: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 357ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9552 - val_loss: 0.1401 - learning_rate: 2.0000e-04
# Epoch 24/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 24: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9552 - val_loss: 0.1433 - learning_rate: 2.0000e-04
# Epoch 25/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 25: val_loss did not improve from 0.09735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9552 - val_loss: 0.1438 - learning_rate: 4.0000e-05
#   Saved training history for Fold 2.
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#
# Fold 2 Metrics:
#   Overall Accuracy: 0.9552
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.8000
#     Recall: 0.8889
#     F1-score: 0.8421
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.80      0.89      0.84         9
#         Zalophus_wollebaeki       0.98      0.97      0.97        58
#
#                    accuracy                           0.96        67
#                   macro avg       0.89      0.93      0.91        67
#                weighted avg       0.96      0.96      0.96        67
#
#
#   Confusion Matrix for Fold 2:
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                            8                    1
# Zalophus_wollebaeki                                    2                   56
#   Confusion Matrix saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_1/confusion_matrix.csv
#
# --- Starting Fold 3/5 ---
#   Results for Fold 3 will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_2
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6343 - loss: 0.6405
# Epoch 1: val_loss improved from inf to 0.36854, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_2/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 9s/step - accuracy: 0.6389 - loss: 0.6436 - val_accuracy: 0.8657 - val_loss: 0.3685 - learning_rate: 0.0010
# Epoch 2/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8438 - loss: 0.3154
# Epoch 2: val_loss improved from 0.36854 to 0.11223, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_2/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 846ms/step - accuracy: 0.8177 - loss: 0.3577 - val_accuracy: 0.9701 - val_loss: 0.1122 - learning_rate: 0.0010
# Epoch 3/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9297 - loss: 0.1950
# Epoch 3: val_loss did not improve from 0.11223
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - accuracy: 0.9162 - loss: 0.2186 - val_accuracy: 0.8209 - val_loss: 0.4457 - learning_rate: 0.0010
# Epoch 4/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9688 - loss: 0.0999
# Epoch 4: val_loss improved from 0.11223 to 0.08379, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_2/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 879ms/step - accuracy: 0.9635 - loss: 0.1033 - val_accuracy: 0.9701 - val_loss: 0.0838 - learning_rate: 0.0010
# Epoch 5/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9844 - loss: 0.0718
# Epoch 5: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 740ms/step - accuracy: 0.9783 - loss: 0.0801 - val_accuracy: 0.9403 - val_loss: 0.1015 - learning_rate: 0.0010
# Epoch 6/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0333
# Epoch 6: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 401ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.9254 - val_loss: 0.1782 - learning_rate: 0.0010
# Epoch 7/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9922 - loss: 0.0173
# Epoch 7: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.9891 - loss: 0.0217 - val_accuracy: 0.9254 - val_loss: 0.2030 - learning_rate: 0.0010
# Epoch 8/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9766 - loss: 0.0258
# Epoch 8: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 413ms/step - accuracy: 0.9813 - loss: 0.0227 - val_accuracy: 0.9403 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 9/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 9: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 401ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9403 - val_loss: 0.1109 - learning_rate: 0.0010
# Epoch 10/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 10: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9403 - val_loss: 0.1037 - learning_rate: 0.0010
# Epoch 11/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 11: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9552 - val_loss: 0.1232 - learning_rate: 0.0010
# Epoch 12/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 12: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9552 - val_loss: 0.1287 - learning_rate: 2.0000e-04
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 13: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9552 - val_loss: 0.1341 - learning_rate: 2.0000e-04
# Epoch 14/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 14: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9552 - val_loss: 0.1378 - learning_rate: 2.0000e-04
# Epoch 15/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 15: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9552 - val_loss: 0.1417 - learning_rate: 2.0000e-04
# Epoch 16/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 16: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9552 - val_loss: 0.1426 - learning_rate: 2.0000e-04
# Epoch 17/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 17: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 747ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9552 - val_loss: 0.1436 - learning_rate: 2.0000e-04
# Epoch 18/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 18: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9552 - val_loss: 0.1443 - learning_rate: 2.0000e-04
# Epoch 19/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 19: val_loss did not improve from 0.08379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 397ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9552 - val_loss: 0.1444 - learning_rate: 4.0000e-05
#   Saved training history for Fold 3.
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#
# Fold 3 Metrics:
#   Overall Accuracy: 0.9701
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.8889
#     Recall: 0.8889
#     F1-score: 0.8889
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.89      0.89      0.89         9
#         Zalophus_wollebaeki       0.98      0.98      0.98        58
#
#                    accuracy                           0.97        67
#                   macro avg       0.94      0.94      0.94        67
#                weighted avg       0.97      0.97      0.97        67
#
#
#   Confusion Matrix for Fold 3:
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                            8                    1
# Zalophus_wollebaeki                                    1                   57
#   Confusion Matrix saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_2/confusion_matrix.csv
#
# --- Starting Fold 4/5 ---
#   Results for Fold 4 will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4971 - loss: 2.1533
# Epoch 1: val_loss improved from inf to 0.94207, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 9s/step - accuracy: 0.4839 - loss: 2.3457 - val_accuracy: 0.2537 - val_loss: 0.9421 - learning_rate: 0.0010
# Epoch 2/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5625 - loss: 0.8349
# Epoch 2: val_loss did not improve from 0.94207
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 729ms/step - accuracy: 0.5590 - loss: 0.9584 - val_accuracy: 0.1343 - val_loss: 1.9355 - learning_rate: 0.0010
# Epoch 3/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5078 - loss: 0.9656
# Epoch 3: val_loss improved from 0.94207 to 0.39183, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5247 - loss: 0.9111 - val_accuracy: 0.8806 - val_loss: 0.3918 - learning_rate: 0.0010
# Epoch 4/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8672 - loss: 0.4560
# Epoch 4: val_loss improved from 0.39183 to 0.31095, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 840ms/step - accuracy: 0.7878 - loss: 0.5006 - val_accuracy: 0.8657 - val_loss: 0.3109 - learning_rate: 0.0010
# Epoch 5/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5703 - loss: 0.5375
# Epoch 5: val_loss did not improve from 0.31095
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.6254 - loss: 0.5126 - val_accuracy: 0.8507 - val_loss: 0.5043 - learning_rate: 0.0010
# Epoch 6/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8750 - loss: 0.3467
# Epoch 6: val_loss did not improve from 0.31095
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - accuracy: 0.8542 - loss: 0.3672 - val_accuracy: 0.7761 - val_loss: 0.5538 - learning_rate: 0.0010
# Epoch 7/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9062 - loss: 0.2970
# Epoch 7: val_loss improved from 0.31095 to 0.27513, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9115 - loss: 0.2976 - val_accuracy: 0.9104 - val_loss: 0.2751 - learning_rate: 0.0010
# Epoch 8/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9688 - loss: 0.2363
# Epoch 8: val_loss improved from 0.27513 to 0.24555, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 815ms/step - accuracy: 0.9705 - loss: 0.2372 - val_accuracy: 0.9403 - val_loss: 0.2455 - learning_rate: 0.0010
# Epoch 9/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9688 - loss: 0.1858
# Epoch 9: val_loss did not improve from 0.24555
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 0.9705 - loss: 0.1886 - val_accuracy: 0.9104 - val_loss: 0.3042 - learning_rate: 0.0010
# Epoch 10/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9609 - loss: 0.1609
# Epoch 10: val_loss did not improve from 0.24555
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.9596 - loss: 0.1617 - val_accuracy: 0.9104 - val_loss: 0.2749 - learning_rate: 0.0010
# Epoch 11/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9688 - loss: 0.1372
# Epoch 11: val_loss improved from 0.24555 to 0.20085, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 853ms/step - accuracy: 0.9705 - loss: 0.1358 - val_accuracy: 0.9403 - val_loss: 0.2008 - learning_rate: 0.0010
# Epoch 12/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.1048
# Epoch 12: val_loss improved from 0.20085 to 0.19890, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 1.0000 - loss: 0.1055 - val_accuracy: 0.9403 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0849
# Epoch 13: val_loss did not improve from 0.19890
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 401ms/step - accuracy: 1.0000 - loss: 0.0844 - val_accuracy: 0.9254 - val_loss: 0.2252 - learning_rate: 0.0010
# Epoch 14/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0662
# Epoch 14: val_loss did not improve from 0.19890
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 1.0000 - loss: 0.0661 - val_accuracy: 0.9254 - val_loss: 0.2225 - learning_rate: 0.0010
# Epoch 15/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9766 - loss: 0.0692
# Epoch 15: val_loss improved from 0.19890 to 0.19396, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 909ms/step - accuracy: 0.9813 - loss: 0.0655 - val_accuracy: 0.9403 - val_loss: 0.1940 - learning_rate: 0.0010
# Epoch 16/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0587
# Epoch 16: val_loss improved from 0.19396 to 0.18519, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 1.0000 - loss: 0.0544 - val_accuracy: 0.9403 - val_loss: 0.1852 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 17: val_loss did not improve from 0.18519
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 360ms/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 0.9403 - val_loss: 0.1868 - learning_rate: 0.0010
# Epoch 18/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0359
# Epoch 18: val_loss improved from 0.18519 to 0.18006, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 840ms/step - accuracy: 1.0000 - loss: 0.0352 - val_accuracy: 0.9403 - val_loss: 0.1801 - learning_rate: 0.0010
# Epoch 19/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 19: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 1.0000 - loss: 0.0289 - val_accuracy: 0.9403 - val_loss: 0.1832 - learning_rate: 0.0010
# Epoch 20/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 20: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.9104 - val_loss: 0.2012 - learning_rate: 0.0010
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 21: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.9254 - val_loss: 0.2191 - learning_rate: 0.0010
# Epoch 22/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 22: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.9254 - val_loss: 0.2101 - learning_rate: 0.0010
# Epoch 23/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 23: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.9403 - val_loss: 0.1885 - learning_rate: 0.0010
# Epoch 24/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 24: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.9403 - val_loss: 0.1827 - learning_rate: 0.0010
# Epoch 25/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 25: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.9403 - val_loss: 0.1865 - learning_rate: 0.0010
# Epoch 26/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 26: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9403 - val_loss: 0.1881 - learning_rate: 2.0000e-04
# Epoch 27/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 27: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9403 - val_loss: 0.1900 - learning_rate: 2.0000e-04
# Epoch 28/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 28: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9254 - val_loss: 0.1924 - learning_rate: 2.0000e-04
# Epoch 29/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 29: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9254 - val_loss: 0.1942 - learning_rate: 2.0000e-04
# Epoch 30/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 30: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 343ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9254 - val_loss: 0.1944 - learning_rate: 2.0000e-04
# Epoch 31/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 31: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9104 - val_loss: 0.1953 - learning_rate: 2.0000e-04
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 32: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 512ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9104 - val_loss: 0.1971 - learning_rate: 2.0000e-04
# Epoch 33/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 33: val_loss did not improve from 0.18006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9104 - val_loss: 0.1973 - learning_rate: 4.0000e-05
#   Saved training history for Fold 4.
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#
# Fold 4 Metrics:
#   Overall Accuracy: 0.9403
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.7778
#     Recall: 0.7778
#     F1-score: 0.7778
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.78      0.78      0.78         9
#         Zalophus_wollebaeki       0.97      0.97      0.97        58
#
#                    accuracy                           0.94        67
#                   macro avg       0.87      0.87      0.87        67
#                weighted avg       0.94      0.94      0.94        67
#
#
#   Confusion Matrix for Fold 4:
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                            7                    2
# Zalophus_wollebaeki                                    2                   56
#   Confusion Matrix saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_3/confusion_matrix.csv
#
# --- Starting Fold 5/5 ---
#   Results for Fold 5 will be saved in: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4
#   Train samples in fold: 269
#   Validation samples in fold: 67
#   Train labels distribution (before balancing): [ 36 233]
#   Val labels distribution: [ 9 58]
#   Train samples AFTER balancing (undersampled): 72
#   Balanced Train labels distribution: [36 36]
#   Class Weights for training: {0: np.float64(1.0), 1: np.float64(1.0)}
#   Training model...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5098 - loss: 0.9826
# Epoch 1: val_loss improved from inf to 0.27046, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 9s/step - accuracy: 0.5109 - loss: 1.0083 - val_accuracy: 0.8657 - val_loss: 0.2705 - learning_rate: 0.0010
# Epoch 2/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7344 - loss: 0.4065
# Epoch 2: val_loss did not improve from 0.27046
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step - accuracy: 0.7561 - loss: 0.3917 - val_accuracy: 0.4776 - val_loss: 0.9888 - learning_rate: 0.0010
# Epoch 3/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8438 - loss: 0.3604
# Epoch 3: val_loss improved from 0.27046 to 0.21815, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.8524 - loss: 0.3425 - val_accuracy: 0.8806 - val_loss: 0.2181 - learning_rate: 0.0010
# Epoch 4/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7578 - loss: 0.3346
# Epoch 4: val_loss improved from 0.21815 to 0.21009, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 903ms/step - accuracy: 0.7886 - loss: 0.3092 - val_accuracy: 0.8806 - val_loss: 0.2101 - learning_rate: 0.0010
# Epoch 5/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9688 - loss: 0.1257
# Epoch 5: val_loss did not improve from 0.21009
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.9705 - loss: 0.1203 - val_accuracy: 0.7910 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 6/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9688 - loss: 0.1194
# Epoch 6: val_loss did not improve from 0.21009
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step - accuracy: 0.9635 - loss: 0.1321 - val_accuracy: 0.8657 - val_loss: 0.2230 - learning_rate: 0.0010
# Epoch 7/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9688 - loss: 0.0735
# Epoch 7: val_loss improved from 0.21009 to 0.16237, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 881ms/step - accuracy: 0.9705 - loss: 0.0813 - val_accuracy: 0.9254 - val_loss: 0.1624 - learning_rate: 0.0010
# Epoch 8/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0650
# Epoch 8: val_loss did not improve from 0.16237
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 729ms/step - accuracy: 1.0000 - loss: 0.0646 - val_accuracy: 0.8955 - val_loss: 0.2010 - learning_rate: 0.0010
# Epoch 9/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 9: val_loss did not improve from 0.16237
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 389ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.8955 - val_loss: 0.3164 - learning_rate: 0.0010
# Epoch 10/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0330
# Epoch 10: val_loss did not improve from 0.16237
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 0.9104 - val_loss: 0.2193 - learning_rate: 0.0010
# Epoch 11/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 11: val_loss improved from 0.16237 to 0.15707, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 834ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.8955 - val_loss: 0.1571 - learning_rate: 0.0010
# Epoch 12/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 12: val_loss improved from 0.15707 to 0.15260, saving model to /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 862ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.9104 - val_loss: 0.1526 - learning_rate: 0.0010
# Epoch 13/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 13: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 488ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.8955 - val_loss: 0.1727 - learning_rate: 0.0010
# Epoch 14/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 14: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 726ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.9104 - val_loss: 0.2307 - learning_rate: 0.0010
# Epoch 15/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 15: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8955 - val_loss: 0.2679 - learning_rate: 0.0010
# Epoch 16/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 16: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 403ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9104 - val_loss: 0.2430 - learning_rate: 0.0010
# Epoch 17/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 17: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9104 - val_loss: 0.2134 - learning_rate: 0.0010
# Epoch 18/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 18: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8955 - val_loss: 0.1929 - learning_rate: 0.0010
# Epoch 19/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 19: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8955 - val_loss: 0.1898 - learning_rate: 0.0010
# Epoch 20/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 20: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 415ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8955 - val_loss: 0.1922 - learning_rate: 2.0000e-04
# Epoch 21/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 21: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8955 - val_loss: 0.1978 - learning_rate: 2.0000e-04
# Epoch 22/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 22: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8955 - val_loss: 0.2052 - learning_rate: 2.0000e-04
# Epoch 23/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 23: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 407ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8955 - val_loss: 0.2124 - learning_rate: 2.0000e-04
# Epoch 24/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 24: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8955 - val_loss: 0.2199 - learning_rate: 2.0000e-04
# Epoch 25/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 25: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 508ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8806 - val_loss: 0.2257 - learning_rate: 2.0000e-04
# Epoch 26/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 26: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 358ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8806 - val_loss: 0.2308 - learning_rate: 2.0000e-04
# Epoch 27/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 27: val_loss did not improve from 0.15260
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8806 - val_loss: 0.2316 - learning_rate: 4.0000e-05
#   Saved training history for Fold 5.
#   Evaluating model on validation set...
# Predicting on validation set:   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#
# Fold 5 Metrics:
#   Overall Accuracy: 0.9104
#   Minority Class (Arctocephalus_galapagoensis):
#     Precision: 0.6364
#     Recall: 0.7778
#     F1-score: 0.7000
#   Full Classification Report:
#                               precision    recall  f1-score   support
#
# Arctocephalus_galapagoensis       0.64      0.78      0.70         9
#         Zalophus_wollebaeki       0.96      0.93      0.95        58
#
#                    accuracy                           0.91        67
#                   macro avg       0.80      0.85      0.82        67
#                weighted avg       0.92      0.91      0.91        67
#
#
#   Confusion Matrix for Fold 5:
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                            7                    2
# Zalophus_wollebaeki                                    4                   54
#   Confusion Matrix saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/fold_4/confusion_matrix.csv
#
# --- K-Fold Cross-Validation Final Results ---
#
# --- Average Confusion Matrix across all Folds (Rounded to 2 decimal places) ---
#                              Arctocephalus_galapagoensis  Zalophus_wollebaeki
# Arctocephalus_galapagoensis                          7.6                  1.4
# Zalophus_wollebaeki                                  2.4                 55.8
# {
#     "Average Overall Accuracy": "0.9435 +/- 0.0198",
#     "Average Minority Precision": "0.7661 +/- 0.0833",
#     "Average Minority Recall": "0.8444 +/- 0.0544",
#     "Average Minority F1-score": "0.8018 +/- 0.0635",
#     "Average Confusion Matrix (rows are true, columns are predicted)": [
#         [
#             7.6,
#             1.4
#         ],
#         [
#             2.4,
#             55.8
#         ]
#     ]
# }
#
# Final K-fold summary metrics and average CM saved to: /content/drive/My Drive/galapagos_seals_annotated_data/my_galapagos_seals_dataset/kfold_results/kfold_summary_metrics.json
